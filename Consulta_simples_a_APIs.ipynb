# %% [markdown]
# <a href="https://colab.research.google.com/github/Gisellesg0/engenharia_de_promptIA/blob/main/Consulta_simples_a_APIs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Consultar a API VIAcep
#
# Este script Python permite consultar a API pública VIAcep fornecendo um Código de Endereçamento Postal (CEP) e exibe as informações de endereço formatadas de maneira legível.

# %%
import ipywidgets as widgets
from IPython.display import display, clear_output

# --- Interface Interativa ---

cep_input = widgets.Text(
    value='',
    placeholder='Digite o CEP (apenas números)',
    description='CEP:',
    disabled=False
)

query_button = widgets.Button(
    description='Consultar CEP',
    disabled=False,
    button_style=''
)

output_area = widgets.Output()

def on_button_click(b):
    with output_area:
        clear_output()
        cep_to_test = cep_input.value
        print(f"Consultando CEP: {cep_to_test}")
        address_info = query_viacep(cep_to_test)

        if address_info:
            print(format_address(address_info))
        else:
            print("Não foi possível obter as informações do endereço para o CEP fornecido.")

query_button.on_click(on_button_click)

display(cep_input, query_button, output_area)
# Out:
# Text(value='', description='CEP:', placeholder='Digite o CEP (apenas números)')
# Button(description='Consultar CEP', style=ButtonStyle())
# Output()
